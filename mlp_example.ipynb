# %%
# ==========================================
# STEP 0: Import Libraries
# ==========================================
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.regularizers import l1, l2
from tensorflow.keras.callbacks import EarlyStopping


# ==========================================
# STEP 1: Load & Preprocess Data
# ==========================================
url = "https://raw.githubusercontent.com/pakornlee/ml_example/e4fe04e97b387f17aaabb53709391f4c364a06c0/customer_data_100.csv"
df = pd.read_csv(url)

# Ordinal Encoding
education_map = {
    "HighSchool": 1,
    "Bachelor": 2,
    "Master": 3,
    "PhD": 4
}
df["education_level"] = df["education_level"].map(education_map)

# One-Hot Encoding (Nominal)
df = pd.get_dummies(
    df,
    columns=["job_type", "city"],
    drop_first=True
)

# Feature / Target
X = df.drop("buy_product", axis=1)
y = df["buy_product"]

print("Data shape:", X.shape)


# ==========================================
# STEP 2: Split CV (90%) & Evaluation (10%)
# ==========================================
X_cv, X_eval, y_cv, y_eval = train_test_split(
    X,
    y,
    test_size=0.10,
    random_state=42,
    stratify=y
)

# Neural Network ต้อง scale
scaler = StandardScaler()
X_cv = scaler.fit_transform(X_cv)
X_eval = scaler.transform(X_eval)

print("CV set size:", X_cv.shape)
print("Evaluation set size:", X_eval.shape)


# ==========================================
# STEP 3: Build MLP with Regularization
# ==========================================
model = Sequential([
    Dense(
        32,
        activation="relu",
        input_shape=(X_cv.shape[1],),
        kernel_regularizer=l1(0.001)    # L1 Regularization
    ),
    Dropout(0.3),                      # Dropout

    Dense(
        16,
        activation="relu",
        kernel_regularizer=l2(0.001)    # L2 Regularization
    ),
    Dropout(0.3),                      # Dropout

    Dense(1, activation="sigmoid")
])

model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy"]
)


# ==========================================
# STEP 3.1: Early Stopping
# ==========================================
early_stop = EarlyStopping(
    monitor="val_loss",
    patience=10,
    restore_best_weights=True
)


# ==========================================
# STEP 3.2: Train Model (Validation Split)
# ==========================================
history = model.fit(
    X_cv,
    y_cv,
    epochs=200,
    batch_size=16,
    validation_split=0.2,   # Validation set จาก CV set
    callbacks=[early_stop],
    verbose=1
)

print("\nTraining stopped at epoch:", len(history.history["loss"]))


# ==========================================
# STEP 4: Final Evaluation on 10% Hold-out Set
# ==========================================
y_eval_pred_prob = model.predict(X_eval)
y_eval_pred = (y_eval_pred_prob > 0.5).astype(int)

print("\nEvaluation Set Accuracy:")
print(accuracy_score(y_eval, y_eval_pred))

print("\nClassification Report (Evaluation Set):")
print(classification_report(y_eval, y_eval_pred))
# Out:
# Data shape: (100, 6)
# CV set size: (90, 6)
# Evaluation set size: (10, 6)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.5327 - loss: 0.7006 - val_accuracy: 0.3333 - val_loss: 0.7552
# Epoch 2/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.4554 - loss: 0.7473 - val_accuracy: 0.4444 - val_loss: 0.7139
# Epoch 3/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5616 - loss: 0.6989 - val_accuracy: 0.5000 - val_loss: 0.6786
# Epoch 4/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6021 - loss: 0.6700 - val_accuracy: 0.6111 - val_loss: 0.6451
# Epoch 5/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7630 - loss: 0.5683 - val_accuracy: 0.7222 - val_loss: 0.6147
# Epoch 6/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6794 - loss: 0.5927 - val_accuracy: 0.9444 - val_loss: 0.5868
# Epoch 7/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6736 - loss: 0.6259 - val_accuracy: 1.0000 - val_loss: 0.5614
# Epoch 8/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9332 - loss: 0.5190 - val_accuracy: 1.0000 - val_loss: 0.5399
# Epoch 9/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8160 - loss: 0.5198 - val_accuracy: 1.0000 - val_loss: 0.5192
# Epoch 10/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8322 - loss: 0.5396 - val_accuracy: 1.0000 - val_loss: 0.4980
# Epoch 11/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8524 - loss: 0.5064 - val_accuracy: 1.0000 - val_loss: 0.4765
# Epoch 12/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8290 - loss: 0.5102 - val_accuracy: 1.0000 - val_loss: 0.4560
# Epoch 13/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9294 - loss: 0.4761 - val_accuracy: 1.0000 - val_loss: 0.4362
# Epoch 14/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8683 - loss: 0.4581 - val_accuracy: 1.0000 - val_loss: 0.4182
# Epoch 15/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8707 - loss: 0.4718 - val_accuracy: 1.0000 - val_loss: 0.4008
# Epoch 16/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9439 - loss: 0.3837 - val_accuracy: 1.0000 - val_loss: 0.3835
# Epoch 17/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8666 - loss: 0.3946 - val_accuracy: 1.0000 - val_loss: 0.3674
# Epoch 18/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9094 - loss: 0.3756 - val_accuracy: 1.0000 - val_loss: 0.3518
# Epoch 19/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9430 - loss: 0.3756 - val_accuracy: 1.0000 - val_loss: 0.3386
# Epoch 20/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9242 - loss: 0.3491 - val_accuracy: 1.0000 - val_loss: 0.3246
# Epoch 21/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9774 - loss: 0.3275 - val_accuracy: 1.0000 - val_loss: 0.3111
# Epoch 22/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9002 - loss: 0.3159 - val_accuracy: 1.0000 - val_loss: 0.2995
# Epoch 23/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9734 - loss: 0.3456 - val_accuracy: 1.0000 - val_loss: 0.2873
# Epoch 24/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9528 - loss: 0.3058 - val_accuracy: 1.0000 - val_loss: 0.2764
# Epoch 25/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9468 - loss: 0.3061 - val_accuracy: 1.0000 - val_loss: 0.2660
# Epoch 26/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9470 - loss: 0.2747 - val_accuracy: 1.0000 - val_loss: 0.2565
# Epoch 27/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9630 - loss: 0.2989 - val_accuracy: 1.0000 - val_loss: 0.2472
# Epoch 28/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9277 - loss: 0.3281 - val_accuracy: 1.0000 - val_loss: 0.2388
# Epoch 29/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9291 - loss: 0.2808 - val_accuracy: 1.0000 - val_loss: 0.2316
# Epoch 30/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9543 - loss: 0.2767 - val_accuracy: 1.0000 - val_loss: 0.2250
# Epoch 31/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9578 - loss: 0.2325 - val_accuracy: 1.0000 - val_loss: 0.2186
# Epoch 32/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9702 - loss: 0.2340 - val_accuracy: 1.0000 - val_loss: 0.2124
# Epoch 33/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9418 - loss: 0.2761 - val_accuracy: 1.0000 - val_loss: 0.2066
# Epoch 34/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9688 - loss: 0.2229 - val_accuracy: 1.0000 - val_loss: 0.2004
# Epoch 35/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9430 - loss: 0.2577 - val_accuracy: 1.0000 - val_loss: 0.1946
# Epoch 36/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9737 - loss: 0.2171 - val_accuracy: 1.0000 - val_loss: 0.1894
# Epoch 37/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8979 - loss: 0.3050 - val_accuracy: 1.0000 - val_loss: 0.1842
# Epoch 38/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9557 - loss: 0.2220 - val_accuracy: 1.0000 - val_loss: 0.1788
# Epoch 39/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9361 - loss: 0.2448 - val_accuracy: 1.0000 - val_loss: 0.1742
# Epoch 40/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9505 - loss: 0.2240 - val_accuracy: 1.0000 - val_loss: 0.1703
# Epoch 41/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9355 - loss: 0.2016 - val_accuracy: 1.0000 - val_loss: 0.1676
# Epoch 42/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9789 - loss: 0.2239 - val_accuracy: 1.0000 - val_loss: 0.1647
# Epoch 43/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9563 - loss: 0.2177 - val_accuracy: 1.0000 - val_loss: 0.1626
# Epoch 44/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9476 - loss: 0.2032 - val_accuracy: 1.0000 - val_loss: 0.1600
# Epoch 45/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9470 - loss: 0.2394 - val_accuracy: 1.0000 - val_loss: 0.1572
# Epoch 46/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9667 - loss: 0.2037 - val_accuracy: 1.0000 - val_loss: 0.1534
# Epoch 47/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9398 - loss: 0.1982 - val_accuracy: 1.0000 - val_loss: 0.1502
# Epoch 48/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9667 - loss: 0.1788 - val_accuracy: 1.0000 - val_loss: 0.1466
# Epoch 49/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9714 - loss: 0.1659 - val_accuracy: 1.0000 - val_loss: 0.1429
# Epoch 50/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9847 - loss: 0.1872 - val_accuracy: 1.0000 - val_loss: 0.1395
# Epoch 51/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9737 - loss: 0.1882 - val_accuracy: 1.0000 - val_loss: 0.1365
# Epoch 52/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9893 - loss: 0.1868 - val_accuracy: 1.0000 - val_loss: 0.1338
# Epoch 53/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9609 - loss: 0.2052 - val_accuracy: 1.0000 - val_loss: 0.1309
# Epoch 54/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9954 - loss: 0.1657 - val_accuracy: 1.0000 - val_loss: 0.1286
# Epoch 55/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9821 - loss: 0.1756 - val_accuracy: 1.0000 - val_loss: 0.1268
# Epoch 56/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9470 - loss: 0.1996 - val_accuracy: 1.0000 - val_loss: 0.1256
# Epoch 57/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9881 - loss: 0.1702 - val_accuracy: 1.0000 - val_loss: 0.1240
# Epoch 58/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9606 - loss: 0.1678 - val_accuracy: 1.0000 - val_loss: 0.1231
# Epoch 59/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9207 - loss: 0.1962 - val_accuracy: 1.0000 - val_loss: 0.1221
# Epoch 60/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9294 - loss: 0.2008 - val_accuracy: 1.0000 - val_loss: 0.1199
# Epoch 61/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9769 - loss: 0.1563 - val_accuracy: 1.0000 - val_loss: 0.1180
# Epoch 62/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9682 - loss: 0.1725 - val_accuracy: 1.0000 - val_loss: 0.1163
# Epoch 63/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9523 - loss: 0.1548 - val_accuracy: 1.0000 - val_loss: 0.1150
# Epoch 64/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9841 - loss: 0.1315 - val_accuracy: 1.0000 - val_loss: 0.1135
# Epoch 65/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9928 - loss: 0.1399 - val_accuracy: 1.0000 - val_loss: 0.1116
# Epoch 66/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9737 - loss: 0.1887 - val_accuracy: 1.0000 - val_loss: 0.1097
# Epoch 67/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9661 - loss: 0.1781 - val_accuracy: 1.0000 - val_loss: 0.1086
# Epoch 68/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9520 - loss: 0.1606 - val_accuracy: 1.0000 - val_loss: 0.1075
# Epoch 69/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9847 - loss: 0.1409 - val_accuracy: 1.0000 - val_loss: 0.1067
# Epoch 70/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9664 - loss: 0.1975 - val_accuracy: 1.0000 - val_loss: 0.1066
# Epoch 71/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9688 - loss: 0.1483 - val_accuracy: 1.0000 - val_loss: 0.1059
# Epoch 72/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9473 - loss: 0.1622 - val_accuracy: 1.0000 - val_loss: 0.1054
# Epoch 73/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9821 - loss: 0.1334 - val_accuracy: 1.0000 - val_loss: 0.1038
# Epoch 74/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9928 - loss: 0.1516 - val_accuracy: 1.0000 - val_loss: 0.1023
# Epoch 75/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9714 - loss: 0.1285 - val_accuracy: 1.0000 - val_loss: 0.1005
# Epoch 76/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9737 - loss: 0.1571 - val_accuracy: 1.0000 - val_loss: 0.0988
# Epoch 77/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9630 - loss: 0.1446 - val_accuracy: 1.0000 - val_loss: 0.0978
# Epoch 78/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9774 - loss: 0.1515 - val_accuracy: 1.0000 - val_loss: 0.0968
# Epoch 79/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9688 - loss: 0.1397 - val_accuracy: 1.0000 - val_loss: 0.0961
# Epoch 80/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9786 - loss: 0.1475 - val_accuracy: 1.0000 - val_loss: 0.0956
# Epoch 81/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9928 - loss: 0.1082 - val_accuracy: 1.0000 - val_loss: 0.0949
# Epoch 82/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9661 - loss: 0.1346 - val_accuracy: 1.0000 - val_loss: 0.0940
# Epoch 83/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9737 - loss: 0.1651 - val_accuracy: 1.0000 - val_loss: 0.0934
# Epoch 84/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9841 - loss: 0.1229 - val_accuracy: 1.0000 - val_loss: 0.0925
# Epoch 85/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9580 - loss: 0.1545 - val_accuracy: 1.0000 - val_loss: 0.0916
# Epoch 86/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9737 - loss: 0.1341 - val_accuracy: 1.0000 - val_loss: 0.0914
# Epoch 87/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9531 - loss: 0.1701 - val_accuracy: 1.0000 - val_loss: 0.0914
# Epoch 88/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9841 - loss: 0.1446 - val_accuracy: 1.0000 - val_loss: 0.0908
# Epoch 89/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9690 - loss: 0.1380 - val_accuracy: 1.0000 - val_loss: 0.0904
# Epoch 90/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9841 - loss: 0.1331 - val_accuracy: 1.0000 - val_loss: 0.0909
# Epoch 91/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9841 - loss: 0.1278 - val_accuracy: 1.0000 - val_loss: 0.0907
# Epoch 92/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9954 - loss: 0.1046 - val_accuracy: 1.0000 - val_loss: 0.0901
# Epoch 93/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9664 - loss: 0.1266 - val_accuracy: 1.0000 - val_loss: 0.0899
# Epoch 94/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9578 - loss: 0.1205 - val_accuracy: 1.0000 - val_loss: 0.0895
# Epoch 95/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9928 - loss: 0.1108 - val_accuracy: 1.0000 - val_loss: 0.0889
# Epoch 96/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9737 - loss: 0.1194 - val_accuracy: 1.0000 - val_loss: 0.0883
# Epoch 97/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.1110 - val_accuracy: 1.0000 - val_loss: 0.0874
# Epoch 98/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.1119 - val_accuracy: 1.0000 - val_loss: 0.0862
# Epoch 99/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9907 - loss: 0.1042 - val_accuracy: 1.0000 - val_loss: 0.0852
# Epoch 100/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9664 - loss: 0.1474 - val_accuracy: 1.0000 - val_loss: 0.0849
# Epoch 101/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9954 - loss: 0.1182 - val_accuracy: 1.0000 - val_loss: 0.0845
# Epoch 102/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9841 - loss: 0.1182 - val_accuracy: 1.0000 - val_loss: 0.0843
# Epoch 103/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9470 - loss: 0.1338 - val_accuracy: 1.0000 - val_loss: 0.0838
# Epoch 104/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9847 - loss: 0.1189 - val_accuracy: 1.0000 - val_loss: 0.0835
# Epoch 105/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9537 - loss: 0.1482 - val_accuracy: 1.0000 - val_loss: 0.0835
# Epoch 106/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9841 - loss: 0.1206 - val_accuracy: 1.0000 - val_loss: 0.0834
# Epoch 107/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9734 - loss: 0.1303 - val_accuracy: 1.0000 - val_loss: 0.0836
# Epoch 108/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9907 - loss: 0.1185 - val_accuracy: 1.0000 - val_loss: 0.0833
# Epoch 109/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.1170 - val_accuracy: 1.0000 - val_loss: 0.0839
# Epoch 110/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9644 - loss: 0.1447 - val_accuracy: 1.0000 - val_loss: 0.0837
# Epoch 111/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9592 - loss: 0.1302 - val_accuracy: 1.0000 - val_loss: 0.0839
# Epoch 112/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9424 - loss: 0.1732 - val_accuracy: 1.0000 - val_loss: 0.0839
# Epoch 113/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9795 - loss: 0.1198 - val_accuracy: 1.0000 - val_loss: 0.0833
# Epoch 114/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9954 - loss: 0.0960 - val_accuracy: 1.0000 - val_loss: 0.0837
# Epoch 115/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9795 - loss: 0.1102 - val_accuracy: 1.0000 - val_loss: 0.0842
# Epoch 116/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.1022 - val_accuracy: 1.0000 - val_loss: 0.0848
# Epoch 117/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9855 - loss: 0.1140 - val_accuracy: 1.0000 - val_loss: 0.0844
# Epoch 118/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9893 - loss: 0.1121 - val_accuracy: 1.0000 - val_loss: 0.0834
# Epoch 119/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9737 - loss: 0.1408 - val_accuracy: 1.0000 - val_loss: 0.0819
# Epoch 120/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.1103 - val_accuracy: 1.0000 - val_loss: 0.0806
# Epoch 121/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9928 - loss: 0.0996 - val_accuracy: 1.0000 - val_loss: 0.0799
# Epoch 122/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.1328 - val_accuracy: 1.0000 - val_loss: 0.0794
# Epoch 123/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9734 - loss: 0.1431 - val_accuracy: 1.0000 - val_loss: 0.0788
# Epoch 124/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9928 - loss: 0.0978 - val_accuracy: 1.0000 - val_loss: 0.0783
# Epoch 125/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9954 - loss: 0.1057 - val_accuracy: 1.0000 - val_loss: 0.0778
# Epoch 126/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9737 - loss: 0.1757 - val_accuracy: 1.0000 - val_loss: 0.0785
# Epoch 127/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9954 - loss: 0.0982 - val_accuracy: 1.0000 - val_loss: 0.0785
# Epoch 128/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9734 - loss: 0.1398 - val_accuracy: 1.0000 - val_loss: 0.0783
# Epoch 129/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9737 - loss: 0.1374 - val_accuracy: 1.0000 - val_loss: 0.0781
# Epoch 130/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9954 - loss: 0.0972 - val_accuracy: 1.0000 - val_loss: 0.0777
# Epoch 131/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9821 - loss: 0.1223 - val_accuracy: 1.0000 - val_loss: 0.0774
# Epoch 132/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9737 - loss: 0.1380 - val_accuracy: 1.0000 - val_loss: 0.0766
# Epoch 133/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9928 - loss: 0.0936 - val_accuracy: 1.0000 - val_loss: 0.0758
# Epoch 134/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9800 - loss: 0.1064 - val_accuracy: 1.0000 - val_loss: 0.0753
# Epoch 135/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0992 - val_accuracy: 1.0000 - val_loss: 0.0756
# Epoch 136/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9690 - loss: 0.1114 - val_accuracy: 1.0000 - val_loss: 0.0757
# Epoch 137/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9841 - loss: 0.1121 - val_accuracy: 1.0000 - val_loss: 0.0754
# Epoch 138/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9734 - loss: 0.1006 - val_accuracy: 1.0000 - val_loss: 0.0752
# Epoch 139/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0944 - val_accuracy: 1.0000 - val_loss: 0.0750
# Epoch 140/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9893 - loss: 0.1172 - val_accuracy: 1.0000 - val_loss: 0.0749
# Epoch 141/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0977 - val_accuracy: 1.0000 - val_loss: 0.0749
# Epoch 142/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9769 - loss: 0.1067 - val_accuracy: 1.0000 - val_loss: 0.0746
# Epoch 143/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9928 - loss: 0.1124 - val_accuracy: 1.0000 - val_loss: 0.0742
# Epoch 144/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9821 - loss: 0.1031 - val_accuracy: 1.0000 - val_loss: 0.0738
# Epoch 145/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0871 - val_accuracy: 1.0000 - val_loss: 0.0733
# Epoch 146/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9954 - loss: 0.1051 - val_accuracy: 1.0000 - val_loss: 0.0732
# Epoch 147/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9893 - loss: 0.1139 - val_accuracy: 1.0000 - val_loss: 0.0738
# Epoch 148/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9928 - loss: 0.0978 - val_accuracy: 1.0000 - val_loss: 0.0744
# Epoch 149/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9893 - loss: 0.1178 - val_accuracy: 1.0000 - val_loss: 0.0752
# Epoch 150/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.1069 - val_accuracy: 1.0000 - val_loss: 0.0759
# Epoch 151/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.1055 - val_accuracy: 1.0000 - val_loss: 0.0761
# Epoch 152/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9954 - loss: 0.1056 - val_accuracy: 1.0000 - val_loss: 0.0754
# Epoch 153/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0920 - val_accuracy: 1.0000 - val_loss: 0.0747
# Epoch 154/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9954 - loss: 0.0908 - val_accuracy: 1.0000 - val_loss: 0.0741
# Epoch 155/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0879 - val_accuracy: 1.0000 - val_loss: 0.0730
# Epoch 156/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9737 - loss: 0.1250 - val_accuracy: 1.0000 - val_loss: 0.0719
# Epoch 157/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0856 - val_accuracy: 1.0000 - val_loss: 0.0711
# Epoch 158/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9523 - loss: 0.1320 - val_accuracy: 1.0000 - val_loss: 0.0702
# Epoch 159/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.0870 - val_accuracy: 1.0000 - val_loss: 0.0698
# Epoch 160/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 0.0979 - val_accuracy: 1.0000 - val_loss: 0.0694
# Epoch 161/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9893 - loss: 0.1077 - val_accuracy: 1.0000 - val_loss: 0.0690
# Epoch 162/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0823 - val_accuracy: 1.0000 - val_loss: 0.0689
# Epoch 163/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9737 - loss: 0.1511 - val_accuracy: 1.0000 - val_loss: 0.0692
# Epoch 164/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9893 - loss: 0.0942 - val_accuracy: 1.0000 - val_loss: 0.0692
# Epoch 165/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0849 - val_accuracy: 1.0000 - val_loss: 0.0693
# Epoch 166/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0875 - val_accuracy: 1.0000 - val_loss: 0.0694
# Epoch 167/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9928 - loss: 0.0986 - val_accuracy: 1.0000 - val_loss: 0.0693
# Epoch 168/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9841 - loss: 0.1019 - val_accuracy: 1.0000 - val_loss: 0.0695
# Epoch 169/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9928 - loss: 0.1070 - val_accuracy: 1.0000 - val_loss: 0.0697
# Epoch 170/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9578 - loss: 0.1390 - val_accuracy: 1.0000 - val_loss: 0.0701
# Epoch 171/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9855 - loss: 0.1101 - val_accuracy: 1.0000 - val_loss: 0.0703
# Epoch 172/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9841 - loss: 0.1042 - val_accuracy: 1.0000 - val_loss: 0.0708
#
# Training stopped at epoch: 172
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
#
# Evaluation Set Accuracy:
# 1.0
#
# Classification Report (Evaluation Set):
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         6
#            1       1.00      1.00      1.00         4
#
#     accuracy                           1.00        10
#    macro avg       1.00      1.00      1.00        10
# weighted avg       1.00      1.00      1.00        10
